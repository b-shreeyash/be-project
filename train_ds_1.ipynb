# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *

ds=pd.read_csv("/content/sample_data/A_2018.02.02_11.21.55.csv")
ds
# Out:
#                Timestamp  Longitude   Latitude  Speed Operatorname  CellID  \
# 0    2018.02.02_11.21.55  -8.656289  52.132759     44            A       2
# 1    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 2    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 3    2018.02.02_11.21.57  -8.656298  52.132711     42            A       2
# 4    2018.02.02_11.21.58  -8.656298  52.132711     42            A       2
# ..                   ...        ...        ...    ...          ...     ...
# 608  2018.02.02_11.34.14  -8.656298  52.132711     42            A       6
# 609  2018.02.02_11.34.15  -8.656298  52.132711     42            A       6
# 610  2018.02.02_11.34.16  -8.656298  52.132711     42            A       6
# 611  2018.02.02_11.34.18  -8.656298  52.132711     42            A       6
# 612  2018.02.02_11.34.18  -8.656298  52.132711     42            A       6
#
# ...

# %%
ds.describe()
# Out:
#           Longitude    Latitude       Speed        CellID        RSRP  \
# count  6.130000e+02  613.000000  613.000000    613.000000  613.000000
# mean  -8.656298e+00   52.132711   42.003263   3805.942904  -85.939641
# std    3.635066e-07    0.000002    0.080779  13759.425286   17.190340
# min   -8.656298e+00   52.132711   42.000000      0.000000 -200.000000
# 25%   -8.656298e+00   52.132711   42.000000      2.000000 -102.000000
# 50%   -8.656298e+00   52.132711   42.000000      6.000000  -81.000000
# 75%   -8.656298e+00   52.132711   42.000000      6.000000  -73.000000
# max   -8.656289e+00   52.132759   44.000000  57094.000000  -51.000000
#
#          DL_bitrate  UL_bitrate
# count    613.000000  613.000000
# mean    5413.768352  114.344209
# std     6446.983454  127.216662
# min        0.000000    0.000000
# 25%     1152.000000   24.000000
# 50%     2930.000000   68.000000
# 75%     7023.000000  159.000000
# max    47543.000000  822.000000
# ...

# %%
symbol_to_replace = "-"
ds.replace(symbol_to_replace, np.nan, inplace=True)
ds
# Out:
#                Timestamp  Longitude   Latitude  Speed Operatorname  CellID  \
# 0    2018.02.02_11.21.55  -8.656289  52.132759     44            A       2
# 1    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 2    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 3    2018.02.02_11.21.57  -8.656298  52.132711     42            A       2
# 4    2018.02.02_11.21.58  -8.656298  52.132711     42            A       2
# ..                   ...        ...        ...    ...          ...     ...
# 608  2018.02.02_11.34.14  -8.656298  52.132711     42            A       6
# 609  2018.02.02_11.34.15  -8.656298  52.132711     42            A       6
# 610  2018.02.02_11.34.16  -8.656298  52.132711     42            A       6
# 611  2018.02.02_11.34.18  -8.656298  52.132711     42            A       6
# 612  2018.02.02_11.34.18  -8.656298  52.132711     42            A       6
#
# ...

# %%
ds.to_csv('cleaned_dataset.csv', index=False)

# %%
ds_1 = pd.read_csv("/content/cleaned_dataset.csv")
ds_1
# Out:
#                Timestamp  Longitude   Latitude  Speed Operatorname  CellID  \
# 0    2018.02.02_11.21.55  -8.656289  52.132759     44            A       2
# 1    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 2    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 3    2018.02.02_11.21.57  -8.656298  52.132711     42            A       2
# 4    2018.02.02_11.21.58  -8.656298  52.132711     42            A       2
# ..                   ...        ...        ...    ...          ...     ...
# 608  2018.02.02_11.34.14  -8.656298  52.132711     42            A       6
# 609  2018.02.02_11.34.15  -8.656298  52.132711     42            A       6
# 610  2018.02.02_11.34.16  -8.656298  52.132711     42            A       6
# 611  2018.02.02_11.34.18  -8.656298  52.132711     42            A       6
# 612  2018.02.02_11.34.18  -8.656298  52.132711     42            A       6
#
# ...

# %%
ds_1.describe()
# Out:
#           Longitude    Latitude       Speed        CellID        RSRP  \
# count  6.130000e+02  613.000000  613.000000    613.000000  613.000000
# mean  -8.656298e+00   52.132711   42.003263   3805.942904  -85.939641
# std    3.635066e-07    0.000002    0.080779  13759.425286   17.190340
# min   -8.656298e+00   52.132711   42.000000      0.000000 -200.000000
# 25%   -8.656298e+00   52.132711   42.000000      2.000000 -102.000000
# 50%   -8.656298e+00   52.132711   42.000000      6.000000  -81.000000
# 75%   -8.656298e+00   52.132711   42.000000      6.000000  -73.000000
# max   -8.656289e+00   52.132759   44.000000  57094.000000  -51.000000
#
#              RSRQ         SNR         CQI        RSSI    DL_bitrate  \
# count  597.000000  256.000000  256.000000  236.000000    613.000000
# mean    -6.678392    4.320312    7.925781  -83.309322   5413.768352
# std      5.703856    6.233916    2.584714   11.059687   6446.983454
# ...

# %%
columns_to_replace = ['RSSI', 'NRxRSRP', 'NRxRSRQ']
ds_1[columns_to_replace] = ds_1[columns_to_replace].fillna(ds_1.mean())
ds_1
# Out:
# <ipython-input-28-c9f377d56e92>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ds_1[columns_to_replace] = ds_1[columns_to_replace].fillna(ds_1.mean())
#                Timestamp  Longitude   Latitude  Speed Operatorname  CellID  \
# 0    2018.02.02_11.21.55  -8.656289  52.132759     44            A       2
# 1    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 2    2018.02.02_11.21.56  -8.656298  52.132711     42            A       2
# 3    2018.02.02_11.21.57  -8.656298  52.132711     42            A       2
# 4    2018.02.02_11.21.58  -8.656298  52.132711     42            A       2
# ..                   ...        ...        ...    ...          ...     ...
# ...

# %%
ds_1.to_csv('filled_dataset.csv', index=False)

# %%
num_rows, num_columns = ds_1.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 613
# Number of columns: 20

# %%
ds_1.describe()
# Out:
#           Longitude    Latitude       Speed        CellID        RSRP  \
# count  6.130000e+02  613.000000  613.000000    613.000000  613.000000
# mean  -8.656298e+00   52.132711   42.003263   3805.942904  -85.939641
# std    3.635066e-07    0.000002    0.080779  13759.425286   17.190340
# min   -8.656298e+00   52.132711   42.000000      0.000000 -200.000000
# 25%   -8.656298e+00   52.132711   42.000000      2.000000 -102.000000
# 50%   -8.656298e+00   52.132711   42.000000      6.000000  -81.000000
# 75%   -8.656298e+00   52.132711   42.000000      6.000000  -73.000000
# max   -8.656289e+00   52.132759   44.000000  57094.000000  -51.000000
#
#              RSRQ         SNR         CQI        RSSI    DL_bitrate  \
# count  597.000000  256.000000  256.000000  613.000000    613.000000
# mean    -6.678392    4.320312    7.925781  -83.309322   5413.768352
# std      5.703856    6.233916    2.584714    6.853321   6446.983454
# ...
